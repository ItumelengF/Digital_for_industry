# %% [markdown]
# # Digital For Industrial Summative - Part 1
#
# ## Creating A Digital Thread

# %% [markdown]
# A Digital Thread is the one unifying theme or characteristic that connects every aspect of an asset or unit, right from its inception and design, to manufacture, deployment, operations, maintenance to eventual retirement.
#
# In analysis, a digital thread is the logical with which we bind and merge the various data sources into one whole, so that it lends itself to quantitative approaches easily.
#
# <img src = 'images/Digital_Thread.JPG' width=500>

# %% [markdown]
# A digital thread is a technique to 'stitch' the data that comes in disjoint tables, such that they can be put together logically. That is a task for this exercise.

# %% [markdown]
# Data sets provided:
#
# We have been give 5 data sets, all of which related to one month's worth of readings taken at a live volcano site. The volcano was instrumented with multiple sensors in 10 different geographical points (nodes). Our goal is to combine and merge all of this into one digital thread, making it amenable for analysis.
#
# Tasks:
#
#     1.0 Read all the needed input files
#     2.0 Plotting Sensor Time Series
#     3.0 Descriptive Analysis One data frame at a time
#     4.0 Creating a Digital Thread from the data sets
#     5.0 Time Series based analysis
#     6.0 Correlations Analysis
#     7.0 Data Manipulations to Merge multiple data sets
#     8.0 Building A Battery Remaining-Life prediction model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os

# %%
# %matplotlib inline

# %% [markdown]
# ### 1.0 Read all the needed input files

# %% [markdown]
# Create multiple data frames, one to hold each data table.

# %% [markdown]
# Convert all Data frame time stamps into date-time format, so that time-based indexing is possible

# %%
data_dir = 'data/Volcano'

# %%
_files = os.listdir(data_dir)

# %%
for file in _files:
    print(file)
# Out:
# datapoints.csv
# datatypes.csv
# nodes.csv
# sensors.csv
# volcanos.csv

# %%
# read data into dataframes 
datapoints = pd.read_csv('datapoints.csv')
datatypes = pd.read_csv('datatypes.csv')
nodes = pd.read_csv('nodes.csv')
sensors = pd.read_csv('sensors.csv')
volcanos = pd.read_csv('volcanos.csv')

# %%
datapoints.head()
# Out:
#                                      id      value               timestamp  \
# 0  764c5e60-8679-11e6-a353-2f6c041e2491     98.000  2016-08-03 04:39:25+00
# 1  764c5e61-8679-11e6-a353-2f6c041e2491     33.198  2016-08-03 04:39:25+00
# 2  764dbdf0-8679-11e6-a353-2f6c041e2491     29.300  2016-08-03 04:39:25+00
# 3  764dbdf1-8679-11e6-a353-2f6c041e2491  96893.110  2016-08-03 04:39:25+00
# 4  764dbdf2-8679-11e6-a353-2f6c041e2491    459.736  2016-08-03 04:39:25+00
#
#                               sensor_id
# 0  7635c920-8679-11e6-a353-2f6c041e2491
# 1  763b9580-8679-11e6-a353-2f6c041e2491
# 2  763ca6f0-8679-11e6-a353-2f6c041e2491
# 3  763d9150-8679-11e6-a353-2f6c041e2491
# 4  763701a1-8679-11e6-a353-2f6c041e2491

# %%
datatypes.head(30)
# Out:
#                                      id                            type  \
# 0  35dcb3c0-8679-11e6-bda3-ef77801087ee                     temperature
# 1  35dcb3c1-8679-11e6-bda3-ef77801087ee                        pressure
# 2  35dcb3c2-8679-11e6-bda3-ef77801087ee                        humidity
# 3  35dcdad0-8679-11e6-bda3-ef77801087ee    carbon dioxide concentration
# 4  35dcdad1-8679-11e6-bda3-ef77801087ee  hydrogen sulfide concentration
# 5  35dcdad2-8679-11e6-bda3-ef77801087ee                         battery
# 6  ed5edee0-e701-11e6-83c1-01ce06e6d17f                            RSAM
#
#              si_unit type_id
# 0            celcius     TCA
# 1             pascal      PA
# 2  relative humidity    HUMA
# 3                ppm  GP_CO2
# 4                ppm  GP_H2S
# 5         percentage     BAT
# 6             counts    RSAM

# %%
nodes.head()
# Out:
#                                      id name description location   status  \
# 0  c5e39fa0-867a-11e6-a353-2f6c041e2491   N1          \N       \N  OFFLINE
# 1  c147ece0-8679-11e6-a353-2f6c041e2491   N9          \N       \N  OFFLINE
# 2  76309900-8679-11e6-a353-2f6c041e2491   N8          \N       \N  OFFLINE
# 3  762b8ff0-8679-11e6-a353-2f6c041e2491  N10          \N       \N  OFFLINE
# 4  c14ccee0-8679-11e6-a353-2f6c041e2491   N2          \N       \N  OFFLINE
#
#                created_at                  updated_at  \
# 0  2016-08-17 01:06:49+00  2016-09-29 19:28:05.932+00
# 1  2016-08-07 00:51:40+00  2016-09-29 19:41:07.065+00
# 2  2016-08-03 22:09:40+00  2016-09-29 19:20:17.417+00
# 3  2016-08-03 04:39:25+00  2016-09-29 19:20:17.431+00
# 4  2016-08-10 04:20:22+00  2016-09-29 19:20:17.523+00
#
#                              volcano_id
# 0  35dc3e90-8679-11e6-bda3-ef77801087ee
# 1  35dc3e90-8679-11e6-bda3-ef77801087ee
# 2  35dc3e90-8679-11e6-bda3-ef77801087ee
# 3  35dc3e90-8679-11e6-bda3-ef77801087ee
# 4  35dc3e90-8679-11e6-bda3-ef77801087ee

# %%
sensors.head()
# Out:
#                                      id description  data_frequency   status  \
# 0  c15a6370-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 1  7635c920-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 2  763b9580-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 3  763ca6f0-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 4  763d9150-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
#
#                created_at                  updated_at  \
# 0  2016-08-07 00:51:40+00  2016-09-29 19:41:07.066+00
# 1  2016-08-03 04:39:25+00  2016-09-29 20:13:52.793+00
# 2  2016-08-03 04:39:25+00  2016-09-29 20:13:52.797+00
# 3  2016-08-03 04:39:25+00  2016-09-29 20:13:52.803+00
# 4  2016-08-03 04:39:25+00  2016-09-29 20:13:52.811+00
#
#                            data_type_id                               node_id
# 0  35dcdad0-8679-11e6-bda3-ef77801087ee  c147ece0-8679-11e6-a353-2f6c041e2491
# 1  35dcdad2-8679-11e6-bda3-ef77801087ee  762b8ff0-8679-11e6-a353-2f6c041e2491
# 2  35dcdad1-8679-11e6-bda3-ef77801087ee  762b8ff0-8679-11e6-a353-2f6c041e2491
# 3  35dcb3c0-8679-11e6-bda3-ef77801087ee  762b8ff0-8679-11e6-a353-2f6c041e2491
# 4  35dcb3c1-8679-11e6-bda3-ef77801087ee  762b8ff0-8679-11e6-a353-2f6c041e2491

# %%
volcanos.head()
# Out:
#                                      id    name  \
# 0  35dc3e90-8679-11e6-bda3-ef77801087ee  Masaya
#
#                                          description  \
# 0  This is the world's biggest, baddest, most evi...
#
#                                    location   status  \
# 0  {11.985318299999999,-86.178342900000004}  OFFLINE
#
#                    created_at                  updated_at
# 0  2016-09-29 19:16:23.419+00  2016-10-07 07:43:05.015+00

# %%
'''for file in os.listdir(data_dir):
    df = pd.read_csv(file)
    df_list.append(df)
    
final_df = df.append(df for df in df_list)'''
# Out:
# 'for file in os.listdir(data_dir):\n    df = pd.read_csv(file)\n    df_list.append(df)\n    \nfinal_df = df.append(df for df in df_list)'

# %%
# check columns for each dataframe
print('datapoints columns', datapoints.columns)
print('datatypes columns', datatypes.columns)
print('nodes columns', nodes.columns)
print('sensors columns', sensors.columns)
print('volcanos columns', volcanos.columns)

#check data types for each dataframe
print('\n=================================================================================')
print('datapoints dtypes', datapoints.dtypes)
print('\ndatatypes dtypes', datatypes.dtypes)
print('\nnodes dtypes', nodes.dtypes)
print('\nsensors dtypes', sensors.dtypes)
print('\nvolcanos dtypes', volcanos.dtypes)
# Out:
# datapoints columns Index(['id', 'value', 'timestamp', 'sensor_id'], dtype='object')
# datatypes columns Index(['id', 'type', 'si_unit', 'type_id'], dtype='object')
# nodes columns Index(['id', 'name', 'description', 'location', 'status', 'created_at',
#        'updated_at', 'volcano_id'],
#       dtype='object')
# sensors columns Index(['id', 'description', 'data_frequency', 'status', 'created_at',
#        'updated_at', 'data_type_id', 'node_id'],
#       dtype='object')
# volcanos columns Index(['id', 'name', 'description', 'location', 'status', 'created_at',
#        'updated_at'],
#       dtype='object')
#
# =================================================================================
# datapoints dtypes id            object
# value        float64
# timestamp     object
# sensor_id     object
# dtype: object
#
# datatypes dtypes id         object
# type       object
# si_unit    object
# type_id    object
# dtype: object
#
# nodes dtypes id             object
# name           object
# description    object
# location       object
# status         object
# created_at     object
# updated_at     object
# volcano_id     object
# dtype: object
#
# sensors dtypes id                object
# description       object
# data_frequency     int64
# status            object
# created_at        object
# updated_at        object
# data_type_id      object
# node_id           object
# dtype: object
#
# volcanos dtypes id             object
# name           object
# description    object
# location       object
# status         object
# created_at     object
# updated_at     object
# dtype: object

# %%
#convert date objects to datetime
datapoints['timestamp'] = datapoints['timestamp'].astype('datetime64[ns]')
nodes['created_at'] = nodes['created_at'].astype('datetime64[ns]')
nodes['updated_at'] = nodes['updated_at'].astype('datetime64[ns]')
sensors['created_at'] = sensors['created_at'].astype('datetime64[ns]')
sensors['updated_at'] = sensors['updated_at'].astype('datetime64[ns]')
volcanos['created_at'] = volcanos['created_at'].astype('datetime64[ns]')
volcanos['updated_at'] = volcanos['updated_at'].astype('datetime64[ns]')

# %%
print('datapoints dtypes', datapoints.dtypes)
print('\ndatatypes dtypes', datatypes.dtypes)
print('\nnodes dtypes', nodes.dtypes)
print('\nsensors dtypes', sensors.dtypes)
print('\nvolcanos dtypes', volcanos.dtypes)
# Out:
# datapoints dtypes id                   object
# value               float64
# timestamp    datetime64[ns]
# sensor_id            object
# dtype: object
#
# datatypes dtypes id         object
# type       object
# si_unit    object
# type_id    object
# dtype: object
#
# nodes dtypes id                     object
# name                   object
# description            object
# location               object
# status                 object
# created_at     datetime64[ns]
# updated_at     datetime64[ns]
# volcano_id             object
# dtype: object
#
# sensors dtypes id                        object
# description               object
# data_frequency             int64
# status                    object
# created_at        datetime64[ns]
# updated_at        datetime64[ns]
# data_type_id              object
# node_id                   object
# dtype: object
#
# volcanos dtypes id                     object
# name                   object
# description            object
# location               object
# status                 object
# created_at     datetime64[ns]
# updated_at     datetime64[ns]
# dtype: object

# %% [markdown]
# ### 2. Plotting Sensor Time Series
#
# Create separate plots for each sensor in the dataset. Store each one in a separate file.
#
# **What (if anything) can we tell about the various sensors from the plots?**

# %%
sensors.set_index('created_at',inplace=True)

# %%
sensors.shape
# Out:
# (61, 7)

# %%
sensors.head()
# Out:
#                                                        id description  \
# created_at
# 2016-08-07 00:51:40  c15a6370-8679-11e6-a353-2f6c041e2491          \N
# 2016-08-03 04:39:25  7635c920-8679-11e6-a353-2f6c041e2491          \N
# 2016-08-03 04:39:25  763b9580-8679-11e6-a353-2f6c041e2491          \N
# 2016-08-03 04:39:25  763ca6f0-8679-11e6-a353-2f6c041e2491          \N
# 2016-08-03 04:39:25  763d9150-8679-11e6-a353-2f6c041e2491          \N
#
#                      data_frequency   status              updated_at  \
# created_at
# 2016-08-07 00:51:40         1800000  OFFLINE 2016-09-29 19:41:07.066
# 2016-08-03 04:39:25         1800000  OFFLINE 2016-09-29 20:13:52.793
# 2016-08-03 04:39:25         1800000  OFFLINE 2016-09-29 20:13:52.797
# 2016-08-03 04:39:25         1800000  OFFLINE 2016-09-29 20:13:52.803
# 2016-08-03 04:39:25         1800000  OFFLINE 2016-09-29 20:13:52.811
#
#                                              data_type_id  \
# created_at
# 2016-08-07 00:51:40  35dcdad0-8679-11e6-bda3-ef77801087ee
# 2016-08-03 04:39:25  35dcdad2-8679-11e6-bda3-ef77801087ee
# 2016-08-03 04:39:25  35dcdad1-8679-11e6-bda3-ef77801087ee
# 2016-08-03 04:39:25  35dcb3c0-8679-11e6-bda3-ef77801087ee
# 2016-08-03 04:39:25  35dcb3c1-8679-11e6-bda3-ef77801087ee
#
#                                                   node_id
# created_at
# 2016-08-07 00:51:40  c147ece0-8679-11e6-a353-2f6c041e2491
# 2016-08-03 04:39:25  762b8ff0-8679-11e6-a353-2f6c041e2491
# 2016-08-03 04:39:25  762b8ff0-8679-11e6-a353-2f6c041e2491
# 2016-08-03 04:39:25  762b8ff0-8679-11e6-a353-2f6c041e2491
# 2016-08-03 04:39:25  762b8ff0-8679-11e6-a353-2f6c041e2491

# %%
sensors.id.nunique()
# Out:
# 61

# %%
sensors.id.value_counts().head()
# Out:
# c15a6372-8679-11e6-a353-2f6c041e2491    1
# 7635f030-8679-11e6-a353-2f6c041e2491    1
# 763701a0-8679-11e6-a353-2f6c041e2491    1
# d3d56040-8679-11e6-a353-2f6c041e2491    1
# 1248ff60-e707-11e6-89c8-314aa4f67f8c    1
# Name: id, dtype: int64

# %%
datapoints.isnull().any()
# Out:
# id           False
# value         True
# timestamp    False
# sensor_id    False
# dtype: bool

# %%
datapoints.isnull().sum()
# Out:
# id                0
# value        113078
# timestamp         0
# sensor_id         0
# dtype: int64

# %%
sensors.rename(columns={'id':'sensor_id'},inplace=True)
datatypes.rename(columns={'id':'data_type_id'},inplace=True)
volcanos.rename(columns={'id':'volcano_id'},inplace=True)
nodes.rename(columns={'id':'node_id'},inplace=True)

# %%
data = pd.merge(datapoints, sensors, on='sensor_id')
data.shape
# Out:
# (176534, 10)

# %%
data.head()
# Out:
#                                      id  value           timestamp  \
# 0  764c5e60-8679-11e6-a353-2f6c041e2491   98.0 2016-08-03 04:39:25
# 1  765251d0-8679-11e6-a353-2f6c041e2491   98.0 2016-08-03 04:47:41
# 2  7655fb50-8679-11e6-a353-2f6c041e2491   98.0 2016-08-03 05:08:52
# 3  7659cbe0-8679-11e6-a353-2f6c041e2491   98.0 2016-08-03 05:14:08
# 4  765dea90-8679-11e6-a353-2f6c041e2491   96.0 2016-08-03 05:28:55
#
#                               sensor_id description  data_frequency   status  \
# 0  7635c920-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 1  7635c920-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 2  7635c920-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 3  7635c920-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 4  7635c920-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
#
#                updated_at                          data_type_id  \
# 0 2016-09-29 20:13:52.793  35dcdad2-8679-11e6-bda3-ef77801087ee
# 1 2016-09-29 20:13:52.793  35dcdad2-8679-11e6-bda3-ef77801087ee
# 2 2016-09-29 20:13:52.793  35dcdad2-8679-11e6-bda3-ef77801087ee
# 3 2016-09-29 20:13:52.793  35dcdad2-8679-11e6-bda3-ef77801087ee
# 4 2016-09-29 20:13:52.793  35dcdad2-8679-11e6-bda3-ef77801087ee
#
#                                 node_id
# 0  762b8ff0-8679-11e6-a353-2f6c041e2491
# 1  762b8ff0-8679-11e6-a353-2f6c041e2491
# 2  762b8ff0-8679-11e6-a353-2f6c041e2491
# 3  762b8ff0-8679-11e6-a353-2f6c041e2491
# 4  762b8ff0-8679-11e6-a353-2f6c041e2491

# %%
data = pd.merge(data, nodes, on='node_id')
data.shape
# Out:
# (176534, 17)

# %%
data = pd.merge(data, volcanos, on='volcano_id')
data.shape
# Out:
# (176534, 23)

# %%
data = pd.merge(data, volcanos, on='volcano_id')
data.shape
# Out:
# (176534, 29)

# %%
data = pd.merge(data, datatypes, on='data_type_id')
data.shape
# Out:
# (176534, 32)

# %%
data.columns
# Out:
# Index(['id', 'value', 'timestamp', 'sensor_id', 'description_x',
#        'data_frequency', 'status_x', 'updated_at_x', 'data_type_id', 'node_id',
#        'name_x', 'description_y', 'location_x', 'status_y', 'created_at_x',
#        'updated_at_y', 'volcano_id', 'name_y', 'description_x', 'location_y',
#        'status_x', 'created_at_y', 'updated_at_x', 'name', 'description_y',
#        'location', 'status_y', 'created_at', 'updated_at_y', 'type', 'si_unit',
#        'type_id'],
#       dtype='object')

# %%
data.dtypes
# Out:
# id                        object
# value                    float64
# timestamp         datetime64[ns]
# sensor_id                 object
# description_x             object
# data_frequency             int64
# status_x                  object
# updated_at_x      datetime64[ns]
# data_type_id              object
# node_id                   object
# name_x                    object
# description_y             object
# location_x                object
# status_y                  object
# created_at_x      datetime64[ns]
# updated_at_y      datetime64[ns]
# volcano_id                object
# name_y                    object
# description_x             object
# location_y                object
# status_x                  object
# created_at_y      datetime64[ns]
# updated_at_x      datetime64[ns]
# name                      object
# description_y             object
# location                  object
# status_y                  object
# created_at        datetime64[ns]
# updated_at_y      datetime64[ns]
# type                      object
# si_unit                   object
# type_id                   object
# dtype: object

# %%
temperature = data.loc[data['type']=="temperature"]
fig = plt.figure(figsize=(15, 5), dpi=200)
plt.scatter(temperature.index, temperature['value'])

# %%
pressure = data.loc[data['type']=="pressure"]
fig = plt.figure(figsize=(15, 5),dpi=200)
plt.scatter(pressure.index, pressure['value'])

# %%
humidity = data.loc[data['type']=="humidity"]
fig = plt.figure(figsize=(15, 5), dpi=200)
plt.scatter(humidity.index, humidity['value'])

# %%
humidity.shape
# Out:
# (28065, 32)

# %%
humidity.isnull().sum()
# Out:
# id                    0
# value             21387
# timestamp             0
# sensor_id             0
# description_x         0
# data_frequency        0
# status_x              0
# updated_at_x          0
# data_type_id          0
# node_id               0
# name_x                0
# description_y         0
# location_x            0
# status_y              0
# created_at_x          0
# updated_at_y          0
# volcano_id            0
# name_y                0
# description_x         0
# location_y            0
# status_x              0
# created_at_y          0
# updated_at_x          0
# name                  0
# description_y         0
# location              0
# status_y              0
# created_at            0
# updated_at_y          0
# type                  0
# si_unit               0
# type_id               0
# dtype: int64

# %%
#humidity["value"] = humidity['value'].replace({'NAN':np.nan}).astype(float)
humidity["value"] = humidity["value"].fillna(value=humidity["value"].mean())
humidity.isnull().sum()
# Out:
# C:\Users\0000690\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# id                0
# value             0
# timestamp         0
# sensor_id         0
# description_x     0
# data_frequency    0
# status_x          0
# updated_at_x      0
# data_type_id      0
# node_id           0
# name_x            0
# description_y     0
# location_x        0
# status_y          0
# created_at_x      0
# updated_at_y      0
# volcano_id        0
# name_y            0
# description_x     0
# location_y        0
# status_x          0
# created_at_y      0
# updated_at_x      0
# name              0
# description_y     0
# location          0
# status_y          0
# created_at        0
# updated_at_y      0
# type              0
# si_unit           0
# type_id           0
# dtype: int64

# %%
humidity.shape
# Out:
# (28065, 32)

# %%
humidity = data.loc[data['type']=="humidity"]
fig = plt.figure(figsize=(15, 5), dpi=200)
plt.scatter(humidity.index, humidity['value'])

# %%
CO2_con = data.loc[data['type']=="carbon dioxide concentration"]
fig = plt.figure(figsize=(15, 5),dpi=200)
plt.scatter(CO2_con.index, CO2_con['value'])

# %%
HydroSulf = data.loc[data['type']=="hydrogen sulfide concentration"]
fig = plt.figure(figsize=(15, 5),dpi=200)
plt.scatter(HydroSulf.index, HydroSulf['value'])

# %%
battery = data.loc[data['type']=="battery"]
fig = plt.figure(figsize=(15, 5),dpi=200)
plt.scatter(battery.index, battery['value'])

# %%
RSAM = data.loc[data['type']=="RSAM"]
fig = plt.figure(figsize=(15, 5),dpi=150)
plt.scatter(RSAM.index, RSAM['value'])

# %% [markdown]
# ### 3.0 Descriptive Analysis One data frame at a time **
#
# 3.1: How many sensors of each type are there?

# %%
data.type_id.value_counts()
# Out:
# BAT       28234
# PA        28067
# HUMA      28065
# TCA       28037
# GP_CO2    27689
# GP_H2S    27626
# RSAM       8816
# Name: type_id, dtype: int64

# %% [markdown]
# ----
#
# ### 4.0 Creating a Digital Thread from the data sets**
#
# **Goal: Merge everything into one wide data table **

# %% [markdown]
# You have two data frames: `sensors` and `types` Merge each sensors with its type. (Hint: Use `pd.merge()`)
#
# Question: What does this achieve? Why should we do this?

# %% [markdown]
# Now take the raw `data` data frame and merge it with all the `sensors` and their types.

# %%
s2 = pd.merge(sensors, datatypes, left_on='data_type_id', right_on='data_type_id')
data2 = datapoints

# %%
full = pd.merge(data2, s2, left_on='sensor_id', right_on='sensor_id')

# %%
full.shape
# Out:
# (176534, 13)

# %% [markdown]
# -----

# %% [markdown]
# ### 5.0 Time Series based analysis
#
# Now, we are going to take this stitiched data frame and use it for our analysis. Specifically, we are going to perform Time-based analysis on this data.
#
#     Step 1: Take the `full` data frame and make the Time Stamp datetime format
#     Step 2: Resample the dataset to the daily level. (One observation per date)
#     Step 3: For the resampled data, calculate the daily mean, min and max values for each sensor.

# %% [markdown]
# Resample to get daily averages.
# Then subset to select the rows you need.

# %%
full.dtypes
# Out:
# id                        object
# value                    float64
# timestamp         datetime64[ns]
# sensor_id                 object
# description               object
# data_frequency             int64
# status                    object
# updated_at        datetime64[ns]
# data_type_id              object
# node_id                   object
# type                      object
# si_unit                   object
# type_id                   object
# dtype: object

# %%
full.set_index('timestamp',inplace=True)

# %%
daily = full[full.type_id=='HUMA']['value'].resample('D')

# %%
daily.mean()
# Out:
# timestamp
# 2016-08-03    66.673333
# 2016-08-04    74.151389
# 2016-08-05    80.208696
# 2016-08-06    53.222222
# 2016-08-07    40.600000
# 2016-08-08          NaN
# 2016-08-09    52.300000
# 2016-08-10          NaN
# 2016-08-11          NaN
# 2016-08-12          NaN
# 2016-08-13          NaN
# 2016-08-14          NaN
# 2016-08-15    82.400719
# 2016-08-16    79.467539
# 2016-08-17    79.915481
# 2016-08-18    87.126642
# 2016-08-19    75.238824
# 2016-08-20    76.951508
# 2016-08-21    85.711416
# 2016-08-22    79.053776
# 2016-08-23    73.888356
# 2016-08-24    72.593364
# 2016-08-25    66.657311
# 2016-08-26    71.262798
# 2016-08-27    57.149000
# 2016-08-28    48.696575
# 2016-08-29    41.727935
# 2016-08-30    38.114228
# 2016-08-31    41.022266
# 2016-09-01    39.399057
#                 ...
# 2016-09-07    29.192233
# 2016-09-08          NaN
# 2016-09-09          NaN
# 2016-09-10          NaN
# 2016-09-11          NaN
# 2016-09-12          NaN
# 2016-09-13          NaN
# 2016-09-14          NaN
# 2016-09-15          NaN
# 2016-09-16          NaN
# 2016-09-17          NaN
# 2016-09-18          NaN
# 2016-09-19          NaN
# 2016-09-20          NaN
# 2016-09-21          NaN
# 2016-09-22          NaN
# 2016-09-23          NaN
# 2016-09-24          NaN
# 2016-09-25          NaN
# 2016-09-26          NaN
# 2016-09-27          NaN
# 2016-09-28          NaN
# 2016-09-29          NaN
# 2016-09-30          NaN
# 2016-10-01          NaN
# 2016-10-02          NaN
# 2016-10-03          NaN
# 2016-10-04          NaN
# 2016-10-05          NaN
# 2016-10-06          NaN
# Freq: D, Name: value, Length: 65, dtype: float64

# %%
daily.max()
# Out:
# timestamp
# 2016-08-03     97.2
# 2016-08-04    100.0
# 2016-08-05     84.6
# 2016-08-06     59.3
# 2016-08-07     53.6
# 2016-08-08      NaN
# 2016-08-09     52.3
# 2016-08-10      NaN
# 2016-08-11      NaN
# 2016-08-12      NaN
# 2016-08-13      NaN
# 2016-08-14      NaN
# 2016-08-15     90.0
# 2016-08-16     91.9
# 2016-08-17    100.0
# 2016-08-18    100.0
# 2016-08-19    100.0
# 2016-08-20    100.0
# 2016-08-21    100.0
# 2016-08-22    100.0
# 2016-08-23    100.0
# 2016-08-24    100.0
# 2016-08-25    100.0
# 2016-08-26    100.0
# 2016-08-27    100.0
# 2016-08-28    100.0
# 2016-08-29    100.0
# 2016-08-30     76.2
# 2016-08-31    100.0
# 2016-09-01    100.0
#               ...
# 2016-09-07    100.0
# 2016-09-08      NaN
# 2016-09-09      NaN
# 2016-09-10      NaN
# 2016-09-11      NaN
# 2016-09-12      NaN
# 2016-09-13      NaN
# 2016-09-14      NaN
# 2016-09-15      NaN
# 2016-09-16      NaN
# 2016-09-17      NaN
# 2016-09-18      NaN
# 2016-09-19      NaN
# 2016-09-20      NaN
# 2016-09-21      NaN
# 2016-09-22      NaN
# 2016-09-23      NaN
# 2016-09-24      NaN
# 2016-09-25      NaN
# 2016-09-26      NaN
# 2016-09-27      NaN
# 2016-09-28      NaN
# 2016-09-29      NaN
# 2016-09-30      NaN
# 2016-10-01      NaN
# 2016-10-02      NaN
# 2016-10-03      NaN
# 2016-10-04      NaN
# 2016-10-05      NaN
# 2016-10-06      NaN
# Freq: D, Name: value, Length: 65, dtype: float64

# %%
daily.min()
# Out:
# timestamp
# 2016-08-03     0.0
# 2016-08-04     0.0
# 2016-08-05    69.0
# 2016-08-06    44.5
# 2016-08-07    27.6
# 2016-08-08     NaN
# 2016-08-09    52.3
# 2016-08-10     NaN
# 2016-08-11     NaN
# 2016-08-12     NaN
# 2016-08-13     NaN
# 2016-08-14     NaN
# 2016-08-15    66.2
# 2016-08-16    52.3
# 2016-08-17    30.7
# 2016-08-18    52.9
# 2016-08-19    32.0
# 2016-08-20     0.0
# 2016-08-21    50.3
# 2016-08-22    38.9
# 2016-08-23    35.7
# 2016-08-24     0.0
# 2016-08-25    17.9
# 2016-08-26     0.0
# 2016-08-27     0.0
# 2016-08-28     0.0
# 2016-08-29     0.0
# 2016-08-30     0.0
# 2016-08-31     0.0
# 2016-09-01     0.0
#               ...
# 2016-09-07     0.0
# 2016-09-08     NaN
# 2016-09-09     NaN
# 2016-09-10     NaN
# 2016-09-11     NaN
# 2016-09-12     NaN
# 2016-09-13     NaN
# 2016-09-14     NaN
# 2016-09-15     NaN
# 2016-09-16     NaN
# 2016-09-17     NaN
# 2016-09-18     NaN
# 2016-09-19     NaN
# 2016-09-20     NaN
# 2016-09-21     NaN
# 2016-09-22     NaN
# 2016-09-23     NaN
# 2016-09-24     NaN
# 2016-09-25     NaN
# 2016-09-26     NaN
# 2016-09-27     NaN
# 2016-09-28     NaN
# 2016-09-29     NaN
# 2016-09-30     NaN
# 2016-10-01     NaN
# 2016-10-02     NaN
# 2016-10-03     NaN
# 2016-10-04     NaN
# 2016-10-05     NaN
# 2016-10-06     NaN
# Freq: D, Name: value, Length: 65, dtype: float64

# %% [markdown]
# ### 6.0 Correlations Analysis
#
# The next task is to perform a correlation analysis.
#
# 1.  Goal: We want to find all the sensors that are strongly correlated to each other.
# 2. One of the reasons for doing this is that if two (or more) sensors are very highly correlated, we only need to keep one out of each correlated set. (This reduces the problem size and also takes care of colinearlity-related unstability in certain calculations.)

# %% [markdown]
# The Correlation heatmap that we are looking for should be along the following lines:
#
#
# <img src = "images/Corr_plot.JPG" width=450>

# %% [markdown]
# First, look for correlations visually.
#
# **Subtask: Plot all the sensors values (of one type) over time.**

# %% [markdown]
# Sub task: Identify all the temperature sensors in the data set. Hint: These are the ones that have the string 'TCA' in their name id's

# %%
criteria = full.type_id == 'TCA'
plt.figure(figsize=(20,10))
full[criteria]['value'].plot()

# %%
s2.columns
# Out:
# Index(['sensor_id', 'description', 'data_frequency', 'status', 'updated_at',
#        'data_type_id', 'node_id', 'type', 'si_unit', 'type_id'],
#       dtype='object')

# %%
s2.head()
# Out:
#                               sensor_id description  data_frequency   status  \
# 0  c15a6370-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 1  7636da90-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 2  76427351-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 3  763701a1-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
# 4  c15fbaa0-8679-11e6-a353-2f6c041e2491          \N         1800000  OFFLINE
#
#                updated_at                          data_type_id  \
# 0 2016-09-29 19:41:07.066  35dcdad0-8679-11e6-bda3-ef77801087ee
# 1 2016-09-30 18:12:04.577  35dcdad0-8679-11e6-bda3-ef77801087ee
# 2 2016-09-29 19:20:17.416  35dcdad0-8679-11e6-bda3-ef77801087ee
# 3 2016-09-29 19:20:17.431  35dcdad0-8679-11e6-bda3-ef77801087ee
# 4 2016-09-29 19:20:17.523  35dcdad0-8679-11e6-bda3-ef77801087ee
#
#                                 node_id                          type si_unit  \
# 0  c147ece0-8679-11e6-a353-2f6c041e2491  carbon dioxide concentration     ppm
# 1  762c5340-8679-11e6-a353-2f6c041e2491  carbon dioxide concentration     ppm
# 2  76309900-8679-11e6-a353-2f6c041e2491  carbon dioxide concentration     ppm
# 3  762b8ff0-8679-11e6-a353-2f6c041e2491  carbon dioxide concentration     ppm
# 4  c14ccee0-8679-11e6-a353-2f6c041e2491  carbon dioxide concentration     ppm
#
#   type_id
# 0  GP_CO2
# 1  GP_CO2
# 2  GP_CO2
# 3  GP_CO2
# 4  GP_CO2

# %%
temp_sensors = [s for s in s2[s2.type_id =='TCA']['sensor_id']]
temperature_senors = [s for t,s in zip(s2['type_id'], s2['sensor_id']) if t=='TCA'] # alternative way

# %% [markdown]
# ** Using Pandas to plot all the temperature sensors on one single plot. **
#
# - Use pandas to loop over each temperature sensor, and plot them one at a time.
# - Hint: Use the following trick to do this is to plot one line at a time, over and over in a loop

# %%
plt.figure(figsize=(20,5), dpi=150)

for s in temp_sensors:
    print(s)
    sub_df = full[full['sensor_id']==s]
    plt.plot(sub_df.index, sub_df['value'], '.')
# Out:
# 763ca6f0-8679-11e6-a353-2f6c041e2491
# c15a6371-8679-11e6-a353-2f6c041e2491
# 7644bd40-8679-11e6-a353-2f6c041e2491
# c15f9391-8679-11e6-a353-2f6c041e2491
# 763bbc90-8679-11e6-a353-2f6c041e2491
# d3cf6cd0-8679-11e6-a353-2f6c041e2491
# d3d909c1-8679-11e6-a353-2f6c041e2491
# d3d53930-8679-11e6-a353-2f6c041e2491
# c5e881a1-867a-11e6-a353-2f6c041e2491
# e6678e91-8679-11e6-a353-2f6c041e2491

# %% [markdown]
# This plot is fine, but all the lines are too close together. We cannot see how each sensor is behaving. For that, we can try drawing "Subplots." In these plots, each sensor gets its own plot (called a 'panel').

# %% [markdown]
# **Creating Subplots - Each sensor gets its own panel**

# %%
fig, axarr = plt.subplots(10, sharex=True)
fig.set_size_inches(20,30) 

plt.figure(figsize=(20,20))
for i,s in enumerate(temp_sensors):
    sub_df = full[full['sensor_id']==s]
    axarr[i].plot(sub_df.index, sub_df['value'], '.')

# %% [markdown]
# **Task: Creating a reshaped Data Frame of just Temperature sensors**
#
# For this, we are going to have each column be 1 sensor... from 1 to 10. The rows will be timestamps, as before.
#
# Hint: pd.pivot() is perfect for this task.

# %%
# df.pivot(index='patient', columns='obs', values='score')

# %%
temp_df = full[full['sensor_id'].isin(temp_sensors)]
del temp_df['timestamp']
temp_df = temp_df.reset_index()
temp_df.pivot(columns='sensor_id', values='value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-4a0b6f3a5ea3> in <module>
#       1 temp_df = full[full['sensor_id'].isin(temp_sensors)]
#       2 del temp_df['timestamp']
# ----> 3 temp_df = temp_df.reset_index()
#       4 temp_df.pivot(columns='sensor_id', values='value')
#       5
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4137                 # to ndarray and maybe infer different dtype
#    4138                 level_values = _maybe_casted_values(lev, lab)
# -> 4139                 new_obj.insert(0, name, level_values)
#    4140
#    4141         new_obj.index = new_index
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3220         value = self._sanitize_column(column, value, broadcast=False)
#    3221         self._data.insert(loc, column, value,
# -> 3222                           allow_duplicates=allow_duplicates)
#    3223
#    3224     def assign(self, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    4336         if not allow_duplicates and item in self.items:
#    4337             # Should this be a different kind of error??
# -> 4338             raise ValueError('cannot insert {}, already exists'.format(item))
#    4339
#    4340         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %% [markdown]
# Since this is a real sensor data set, there are some time stamps and sensor_id's that are repeating. (Unfortunately, this happens often in real data sets.)
#
# **Task: Find all rows with the same [Timestamp, Sensor_id] and delete them **

# %% [markdown]
# **Here's a clever way to find out all the duplicated rows.**
#
# Some Timestamp and sensor_id are repeating. That causes Indexing problems.

# %%
#pd.concat(g for _, g in df.groupby("ID") if len(g) > 1)
pd.concat(g for _, g in temp_df.groupby(['timestamp', 'sensor_id']) if len(g) > 1)
# Out:
#                                                        id   value  \
# timestamp
# 2016-08-20 20:46:05  0d35cdd0-867e-11e6-a353-2f6c041e2491   25.64
# 2016-08-20 20:46:05  0d34bc60-867e-11e6-a353-2f6c041e2491   25.64
# 2016-08-21 08:21:30  a29f50d0-867e-11e6-a353-2f6c041e2491 -144.12
762c5340-8679-11e6-a353-2f6c041e2491  temperature
# 2016-10-06 04:49:53  762c5340-8679-11e6-a353-2f6c041e2491  temperature
# 2016-10-06 04:49:53  762c5340-8679-11e6-a353-2f6c041e2491  temperature
#
#                      si_unit type_id
# timestamp
# 2016-08-20 20:46:05  celcius     TCA
# 2016-08-20 20:46:05  celcius     TCA
# 2016-08-21 08:21:30  celcius     TCA
# 2016-08-21 08:21:30  celcius     TCA
# 2016-08-21 08:51:26  celcius     TCA
# 2016-08-21 08:51:26  celcius     TCA
# 2016-08-21 09:15:37  celcius     TCA
# 2016-08-21 09:15:37  celcius     TCA
# 2016-08-21 15:45:34  celcius     TCA
# 2016-08-21 15:45:34  celcius     TCA
# 2016-08-21 19:39:40  celcius     TCA
# 2016-08-21 19:39:40  celcius     TCA
# 2016-08-22 03:38:27  celcius     TCA
# 2016-08-22 03:38:27  celcius     TCA
# 2016-08-22 03:45:06  celcius     TCA
# 2016-08-22 03:45:06  celcius     TCA
# 2016-08-22 16:51:32  celcius     TCA
# 2016-08-22 16:51:32  celcius     TCA
# 2016-08-22 18:38:53  celcius     TCA
# 2016-08-22 18:38:53  celcius     TCA
# 2016-08-23 06:40:46  celcius     TCA
# 2016-08-23 06:40:46  celcius     TCA
# 2016-08-23 10:36:21  celcius     TCA
# 2016-08-23 10:36:21  celcius     TCA
# 2016-08-23 14:02:58  celcius     TCA
# 2016-08-23 14:02:58  celcius     TCA
# 2016-08-24 00:45:08  celcius     TCA
# 2016-08-24 00:45:08  celcius     TCA
# 2016-08-24 16:37:22  celcius     TCA
# 2016-08-24 16:37:22  celcius     TCA
# ...                      ...     ...
# 2016-09-29 18:33:13  celcius     TCA
# 2016-09-29 18:33:13  celcius     TCA
# 2016-09-29 19:31:22  celcius     TCA
# 2016-09-29 19:31:22  celcius     TCA
# 2016-09-29 19:33:09  celcius     TCA
# 2016-09-29 19:33:09  celcius     TCA
# 2016-09-29 19:34:55  celcius     TCA
# 2016-09-29 19:34:55  celcius     TCA
# 2016-09-30 02:00:24  celcius     TCA
# 2016-09-30 02:00:24  celcius     TCA
# 2016-09-30 02:02:13  celcius     TCA
# 2016-09-30 02:02:13  celcius     TCA
# 2016-10-03 01:07:06  celcius     TCA
# 2016-10-03 01:07:06  celcius     TCA
# 2016-10-03 01:37:11  celcius     TCA
# 2016-10-03 01:37:11  celcius     TCA
# 2016-10-03 23:55:03  celcius     TCA
# 2016-10-03 23:55:03  celcius     TCA
# 2016-10-03 23:56:23  celcius     TCA
# 2016-10-03 23:56:23  celcius     TCA
# 2016-10-04 22:24:54  celcius     TCA
# 2016-10-04 22:24:54  celcius     TCA
# 2016-10-05 12:21:39  celcius     TCA
# 2016-10-05 12:21:39  celcius     TCA
# 2016-10-05 16:37:33  celcius     TCA
# 2016-10-05 16:37:33  celcius     TCA
# 2016-10-06 04:25:36  celcius     TCA
# 2016-10-06 04:25:36  celcius     TCA
# 2016-10-06 04:49:53  celcius     TCA
# 2016-10-06 04:49:53  celcius     TCA
#
# [1050 rows x 12 columns]

# %% [markdown]
# **Task: Drop all the rows where timestamp and sensor_id are duplicated**

# %%
tdf = temp_df.drop_duplicates(subset = ['timestamp', 'sensor_id'], keep='first')
# Hint: Look at https://segment.com/blog/5-advanced-testing-techniques-in-go/

# %%
#temp_df_cor = tdf.pivot(index='timestamp', columns='sensor_id', values='value')

# %%
#daily_temp_cor_df = temp_df_cor.resample('D').mean()

# %% [markdown]
# Now, we are finally ready to calculate the correlations across sensor values. Hint: `Use corr()`

# %%
#corr_df = daily_temp_cor_df.corr()

# %%
# Create a mask to display only the lower triangle of the matrix (since it's mirrored around its 
# top-left to bottom-right diagonal).
mask = np.zeros_like(corr_df)
mask[np.triu_indices_from(mask)] = True

# %%
# Create the heatmap using seaborn library. 
# List if colormaps (parameter 'cmap') is available here: http://matplotlib.org/examples/color/colormaps_reference.html
sns.heatmap(corr_df, cmap='RdYlGn_r', vmax=1.0, vmin=-1.0 , mask = mask, linewidths=2.5)
 
# Show the plot we reorient the labels for each column and row to make them easier to read.
plt.yticks(rotation=0) 
plt.xticks(rotation=90) 
plt.show()

# %%
full2 = full.drop_duplicates(subset = ['timestamp', 'sensor_id'], keep='first')

# %%
full_wide = full2.pivot(index='timestamp', columns='sensor_id', values='value')

# %%
daily_all_sensors = full_wide.resample('D').mean()

# %%
daily_all_sensors

# %% [markdown]
# **Trying to building a Linear Model**
#
# In order to do that, we first need to create a data frame with the columns representing only those sensors for ONE NODE.
#
# Try to see if pd.pivot() can help with grouping Nodes together

# %%
nodes.name # so we have 10 "nodes" with 6 sensors each. [T, Pr, HUMA, PPM , PPM2, BATT]

# %%
fullnode = pd.merge(full, nodes, left_on='node_id', right_on='id')

# %%
fullnode.columns, fullnode.index

# %%
fullnode.set_index('timestamp', inplace=True)

# %%
fullnode.resample('D').mean()

# %%
# fullnode.pivot_table(index=['timestamp', 'name'], columns='type', values='value')
fn_wide = fullnode.pivot_table(index=['timestamp','name'], columns=['type'], values='value')

# %%
#Now, let's make the Node ('name') into its own column. We do this by reset_index() for that level (=1)
fn_wide.reset_index(level=1, inplace=True)

# %%
fn_wide.head()

# %% [markdown]
# Before we can perform Linear Regression, we have one last step remaining. We'd like to "resample" all the data, aggregating it down to 'Daily' Levels.

# %%
lmfn = fn_wide.resample('D').mean()

# %%
lmfn.shape

# %% [markdown]
# ### End of Stitching.
#
# **The Digital Thread for this dataset has been created**
#
# This "digital Thread" has been used to 'stitch' the data frame with all the values we wish to analyze.
#
# ---
# Now we finally have the data frame in the shape we wanted to enable Linear Regression.
#
# ### 8.0 Sample Modeling

# %% [markdown]
# **8.1 Building A Battery Remaining-Life prediction model **
# Build a machine learning model (LR, tree-based or any other) to try and predict the Battery life (remaining) as a function of any of the other sensor characteristic.
#
# * Which variable (sensor) is a good predictor of battery life?
# * Is your linear regression a "good fit?"
# * What it the RMSE of your predicted values?

# %%
#==============================================================================
# Supervised learning linear regression
#==============================================================================

from sklearn import linear_model

# Split the data into training/testing sets
train = lmfn[:-30]
test = lmfn[-30:]

# %%
train.columns

# %%
target, predictors = 'battery', 'temperature'

x_train=train[predictors].to_frame() #converts the pandas Series to numpy.ndarray
y_train=train[target].to_frame()
x_test=test[predictors].to_frame() #converts the pandas Series to numpy.ndarray
y_test=test[target].to_frame()

# %%
# 2.- Create linear regression object
regr = linear_model.LinearRegression()

# 3.- Train the model using the training sets
regr.fit(x_train,y_train)

# The coefficients
print("Coefficients: ",  float(regr.coef_))
# The mean squared error
print("Mean squared error: %.2f"
      % np.mean((regr.predict(x_train) - y_train) ** 2))
